# %% [markdown]
# Ignores shell warnings and preserves interactivity

# %%
import warnings
warnings.simplefilter('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Basic data science libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-dark')

# %% [markdown]
# Data Preprocessing steps

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold

# %% [markdown]
# ML libraries

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Loading the data set

# %%
df = pd.read_csv('/content/trainyl.csv')

# %% [markdown]
# Dividing variables based on data types

# %%
ID_COL, TARGET_COL = 'video_id', 'views'

num_cols = ['likes', 'dislikes', 'comment_count']
cat_cols = ['category_id', 'country_code']
text_cols = ['title', 'channel_title', 'tags', 'description']
date_cols = ['publish_date']

# %% [markdown]
# Shape of the data set

# %%
df.shape
# Out:
# (26061, 12)

# %% [markdown]
# Closer look on data

# %%
df.head(3)
# Out:
#    video_id  ...   likes
# 0     53364  ...  2351.0
# 1     51040  ...  3264.0
# 2      1856  ...   580.0
#
# [3 rows x 12 columns]

# %% [markdown]
# Drop the duplicates to avoid unnecessary training

# %%
df.drop_duplicates()
# Out:
#        video_id  ...    likes
# 0         53364  ...   2351.0
# 1         51040  ...   3264.0
# 2          1856  ...    580.0
# 3         22618  ...  82773.0
# 4         74074  ...   3557.0
# ...         ...  ...      ...
# 26056     73469  ...   7256.0
# 26057     45412  ...   1468.0
# 26058     61555  ...  40282.0
# 26059     45134  ...   4247.0
# 26060      5968  ...   2236.0
#
# [26061 rows x 12 columns]

# %% [markdown]
# Let's the numerical variables range

# %%
df.describe()
# Out:
#            video_id   category_id  ...  comment_count         likes
# count  26061.000000  26061.000000  ...   26061.000000  2.606100e+04
# mean   44560.500518     21.498292  ...    1693.145620  1.258067e+04
# std    25688.103401      6.304901  ...    9247.594359  5.856355e+04
# min        2.000000      1.000000  ...       0.000000  0.000000e+00
# 25%    22523.000000     22.000000  ...      93.000000  6.830000e+02
# 50%    44648.000000     24.000000  ...     389.000000  2.541000e+03
# 75%    66744.000000     25.000000  ...    1211.000000  8.553000e+03
# max    89272.000000     43.000000  ...  692312.000000  3.880088e+06
#
# [8 rows x 6 columns]

# %% [markdown]
# Getting dummies for string variables to get numerical values on them

# %%
df = pd.get_dummies(df, columns = cat_cols)

# %% [markdown]
# Converting numerical variables to log(Value) to reduce outlier effect and bring axis scale smaller.

# %%
df[num_cols + ['views']] = df[num_cols + ['views']].apply(lambda x: np.log1p(x))

# %% [markdown]
# Fill Null values with 0

# %%
df = df.fillna(0)

# %% [markdown]
# Converting date variable to year, month and day

# %%
df['publish_date'] = pd.to_datetime(df['publish_date'], format='%Y-%m-%d')
df['publish_date_days_since_start'] = (df['publish_date'] - df['publish_date'].min()).dt.days

df['publish_date_day_of_week'] = df['publish_date'].dt.dayofweek
df['publish_date_year'] = df['publish_date'].dt.year
df['publish_date_month'] = df['publish_date'].dt.month

# %% [markdown]
# Select Top 50 description, title and tags count for ML training

# %%
from sklearn.feature_extraction.text import CountVectorizer

TOP_N_WORDS = 750

vec = CountVectorizer(max_features = TOP_N_WORDS)
txt_to_ft1 = vec.fit_transform(df['description']).toarray()
txt_to_ft2 = vec.fit_transform(df['tags']).toarray()
txt_to_ft3 = vec.fit_transform(df['title']).toarray()

# %%
e = 'description'
txt_fts_name1 = [e + f'_word_{i}_count' for i in range(TOP_N_WORDS)]
df[txt_fts_name1] = txt_to_ft1

a = 'tags'
txt_fts_name2 = [a + f'_word_{i}_count' for i in range(TOP_N_WORDS)]
df[txt_fts_name2] = txt_to_ft2

z = 'title'
txt_fts_name3 = [z + f'_word_{i}_count' for i in range(TOP_N_WORDS)]
df[txt_fts_name3] = txt_to_ft3

# %%
a = ['likes', 'dislikes', 'comment_count','views']

# %%
_ = sns.heatmap(df[a].corr(),annot=True, cmap='Greens')

# %% [markdown]
# Neglecting ID and target

# %%
features = [c for c in df.columns if c not in [ID_COL, TARGET_COL]]

# %% [markdown]
# Splitting data into validation for performance

# %%
trn, val = train_test_split(df, test_size=0.3, random_state = 1)

###### Input to our model will be the features
X_trn, X_val = trn[features], val[features]

###### Output of our model will be the TARGET_COL
y_trn, y_val = trn[TARGET_COL], val[TARGET_COL]

# %% [markdown]
# ML performance RMSE

# %%
from sklearn.metrics import mean_squared_error

def av_metric(y_true, y_pred):
  return 1000 * np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# Linear Regression using only numerical columns

# %%
clf = LinearRegression()

_ = clf.fit(X_trn[num_cols], y_trn)

preds_val = clf.predict(X_val[num_cols])

av_metric_score = av_metric(y_val, preds_val)

print(f'AV metric score is: {av_metric_score}')
# Out:
# AV metric score is: 744.3870253291651

# %%
features = [c for c in X_trn.columns if c not in [ID_COL, TARGET_COL]]
cat_num_cols = [c for c in features if c not in text_cols + date_cols]

# %% [markdown]
# Linear Regression training for numerical, categorical, date and text columns

# %%
cat_num_cols
# Out:
# ['dislikes',
#  'comment_count',
#  'likes',
#  'category_id_1.0',
#  'category_id_2.0',
#  'category_id_10.0',
#  'category_id_15.0',
#  'category_id_17.0',
#  'category_id_19.0',
#  'category_id_20.0',
#  'category_id_22.0',
#  'category_id_23.0',
#  'category_id_24.0',
#  'category_id_25.0',
#  'category_id_26.0',
#  'category_id_27.0',
#  'category_id_28.0',
#  'category_id_29.0',
#  'category_id_30.0',
#  'category_id_43.0',
#  'country_code_CA',
#  'country_code_GB',
#  'country_code_IN',
#  'country_code_US',
#  'publish_date_days_since_start',
#  'publish_date_day_of_week',
#  'publish_date_year',
#  'publish_date_month',
#  'description_word_0_count',
#  'description_word_1_count',
#  'description_word_2_count',
#  'description_word_3_count',
#  'description_word_4_count',
#  'description_word_5_count',
#  'description_word_6_count',
#  'description_word_7_count',
#  'description_word_8_count',
#  'description_word_9_count',
#  'description_word_10_count',
#  'description_word_11_count',
#  'description_word_12_count',
#  'description_word_13_count',
#  'description_word_14_count',
#  'description_word_15_count',
#  'description_word_16_count',
#  'description_word_17_count',
#  'description_word_18_count',
#  'description_word_19_count',
#  'description_word_20_count',
#  'description_word_21_count',
#  'description_word_22_count',
#  'description_word_23_count',
#  'description_word_24_count',
#  'description_word_25_count',
#  'description_word_26_count',
#  'description_word_27_count',
#  'description_word_28_count',
#  'description_word_29_count',
#  'description_word_30_count',
#  'description_word_31_count',
#  'description_word_32_count',
#  'description_word_33_count',
#  'description_word_34_count',
#  'description_word_35_count',
#  'description_word_36_count',
#  'description_word_37_count',
#  'description_word_38_count',
#  'description_word_39_count',
#  'description_word_40_count',
#  'description_word_41_count',
#  'description_word_42_count',
#  'description_word_43_count',
#  'description_word_44_count',
#  'description_word_45_count',
#  'description_word_46_count',
#  'description_word_47_count',
#  'description_word_48_count',
#  'description_word_49_count',
#  'description_word_50_count',
#  'description_word_51_count',
#  'description_word_52_count',
#  'description_word_53_count',
#  'description_word_54_count',
#  'description_word_55_count',
#  'description_word_56_count',
#  'description_word_57_count',
#  'description_word_58_count',
#  'description_word_59_count',
#  'description_word_60_count',
#  'description_word_61_count',
#  'description_word_62_count',
#  'description_word_63_count',
#  'description_word_64_count',
#  'description_word_65_count',
#  'description_word_66_count',
#  'description_word_67_count',
#  'description_word_68_count',
#  'description_word_69_count',
#  'description_word_70_count',
#  'description_word_71_count',
#  'description_word_72_count',
#  'description_word_73_count',
#  'description_word_74_count',
#  'description_word_75_count',
#  'description_word_76_count',
#  'description_word_77_count',
#  'description_word_78_count',
#  'description_word_79_count',
#  'description_word_80_count',
#  'description_word_81_count',
#  'description_word_82_count',
#  'description_word_83_count',
#  'description_word_84_count',
#  'description_word_85_count',
#  'description_word_86_count',
#  'description_word_87_count',
#  'description_word_88_count',
#  'description_word_89_count',
#  'description_word_90_count',
#  'description_word_91_count',
#  'description_word_92_count',
#  'description_word_93_count',
#  'description_word_94_count',
#  'description_word_95_count',
#  'description_word_96_count',
#  'description_word_97_count',
#  'description_word_98_count',
#  'description_word_99_count',
#  'description_word_100_count',
#  'description_word_101_count',
#  'description_word_102_count',
#  'description_word_103_count',
#  'description_word_104_count',
#  'description_word_105_count',
#  'description_word_106_count',
#  'description_word_107_count',
#  'description_word_108_count',
#  'description_word_109_count',
#  'description_word_110_count',
#  'description_word_111_count',
#  'description_word_112_count',
#  'description_word_113_count',
#  'description_word_114_count',
#  'description_word_115_count',
#  'description_word_116_count',
#  'description_word_117_count',
#  'description_word_118_count',
#  'description_word_119_count',
#  'description_word_120_count',
#  'description_word_121_count',
#  'description_word_122_count',
#  'description_word_123_count',
#  'description_word_124_count',
#  'description_word_125_count',
#  'description_word_126_count',
#  'description_word_127_count',
#  'description_word_128_count',
#  'description_word_129_count',
#  'description_word_130_count',
#  'description_word_131_count',
#  'description_word_132_count',
#  'description_word_133_count',
#  'description_word_134_count',
#  'description_word_135_count',
#  'description_word_136_count',
#  'description_word_137_count',
#  'description_word_138_count',
#  'description_word_139_count',
#  'description_word_140_count',
#  'description_word_141_count',
#  'description_word_142_count',
#  'description_word_143_count',
#  'description_word_144_count',
#  'description_word_145_count',
#  'description_word_146_count',
#  'description_word_147_count',
#  'description_word_148_count',
#  'description_word_149_count',
#  'description_word_150_count',
#  'description_word_151_count',
#  'description_word_152_count',
#  'description_word_153_count',
#  'description_word_154_count',
#  'description_word_155_count',
#  'description_word_156_count',
#  'description_word_157_count',
#  'description_word_158_count',
#  'description_word_159_count',
#  'description_word_160_count',
#  'description_word_161_count',
#  'description_word_162_count',
#  'description_word_163_count',
#  'description_word_164_count',
#  'description_word_165_count',
#  'description_word_166_count',
#  'description_word_167_count',
#  'description_word_168_count',
#  'description_word_169_count',
#  'description_word_170_count',
#  'description_word_171_count',
#  'description_word_172_count',
#  'description_word_173_count',
#  'description_word_174_count',
#  'description_word_175_count',
#  'description_word_176_count',
#  'description_word_177_count',
#  'description_word_178_count',
#  'description_word_179_count',
#  'description_word_180_count',
#  'description_word_181_count',
#  'description_word_182_count',
#  'description_word_183_count',
#  'description_word_184_count',
#  'description_word_185_count',
#  'description_word_186_count',
#  'description_word_187_count',
#  'description_word_188_count',
#  'description_word_189_count',
#  'description_word_190_count',
#  'description_word_191_count',
#  'description_word_192_count',
#  'description_word_193_count',
#  'description_word_194_count',
#  'description_word_195_count',
#  'description_word_196_count',
#  'description_word_197_count',
#  'description_word_198_count',
#  'description_word_199_count',
#  'description_word_200_count',
#  'description_word_201_count',
#  'description_word_202_count',
#  'description_word_203_count',
#  'description_word_204_count',
#  'description_word_205_count',
#  'description_word_206_count',
#  'description_word_207_count',
#  'description_word_208_count',
#  'description_word_209_count',
#  'description_word_210_count',
#  'description_word_211_count',
#  'description_word_212_count',
#  'description_word_213_count',
#  'description_word_214_count',
#  'description_word_215_count',
#  'description_word_216_count',
#  'description_word_217_count',
#  'description_word_218_count',
#  'description_word_219_count',
#  'description_word_220_count',
#  'description_word_221_count',
#  'description_word_222_count',
#  'description_word_223_count',
#  'description_word_224_count',
#  'description_word_225_count',
#  'description_word_226_count',
#  'description_word_227_count',
#  'description_word_228_count',
#  'description_word_229_count',
#  'description_word_230_count',
#  'description_word_231_count',
#  'description_word_232_count',
#  'description_word_233_count',
#  'description_word_234_count',
#  'description_word_235_count',
#  'description_word_236_count',
#  'description_word_237_count',
#  'description_word_238_count',
#  'description_word_239_count',
#  'description_word_240_count',
#  'description_word_241_count',
#  'description_word_242_count',
#  'description_word_243_count',
#  'description_word_244_count',
#  'description_word_245_count',
#  'description_word_246_count',
#  'description_word_247_count',
#  'description_word_248_count',
#  'description_word_249_count',
#  'description_word_250_count',
#  'description_word_251_count',
#  'description_word_252_count',
#  'description_word_253_count',
#  'description_word_254_count',
#  'description_word_255_count',
#  'description_word_256_count',
#  'description_word_257_count',
#  'description_word_258_count',
#  'description_word_259_count',
#  'description_word_260_count',
#  'description_word_261_count',
#  'description_word_262_count',
#  'description_word_263_count',
#  'description_word_264_count',
#  'description_word_265_count',
#  'description_word_266_count',
#  'description_word_267_count',
#  'description_word_268_count',
#  'description_word_269_count',
#  'description_word_270_count',
#  'description_word_271_count',
#  'description_word_272_count',
#  'description_word_273_count',
#  'description_word_274_count',
#  'description_word_275_count',
#  'description_word_276_count',
#  'description_word_277_count',
#  'description_word_278_count',
#  'description_word_279_count',
#  'description_word_280_count',
#  'description_word_281_count',
#  'description_word_282_count',
#  'description_word_283_count',
#  'description_word_284_count',
#  'description_word_285_count',
#  'description_word_286_count',
#  'description_word_287_count',
#  'description_word_288_count',
#  'description_word_289_count',
#  'description_word_290_count',
#  'description_word_291_count',
#  'description_word_292_count',
#  'description_word_293_count',
#  'description_word_294_count',
#  'description_word_295_count',
#  'description_word_296_count',
#  'description_word_297_count',
#  'description_word_298_count',
#  'description_word_299_count',
#  'description_word_300_count',
#  'description_word_301_count',
#  'description_word_302_count',
#  'description_word_303_count',
#  'description_word_304_count',
#  'description_word_305_count',
#  'description_word_306_count',
#  'description_word_307_count',
#  'description_word_308_count',
#  'description_word_309_count',
#  'description_word_310_count',
#  'description_word_311_count',
#  'description_word_312_count',
#  'description_word_313_count',
#  'description_word_314_count',
#  'description_word_315_count',
#  'description_word_316_count',
#  'description_word_317_count',
#  'description_word_318_count',
#  'description_word_319_count',
#  'description_word_320_count',
#  'description_word_321_count',
#  'description_word_322_count',
#  'description_word_323_count',
#  'description_word_324_count',
#  'description_word_325_count',
#  'description_word_326_count',
#  'description_word_327_count',
#  'description_word_328_count',
#  'description_word_329_count',
#  'description_word_330_count',
#  'description_word_331_count',
#  'description_word_332_count',
#  'description_word_333_count',
#  'description_word_334_count',
#  'description_word_335_count',
#  'description_word_336_count',
#  'description_word_337_count',
#  'description_word_338_count',
#  'description_word_339_count',
#  'description_word_340_count',
#  'description_word_341_count',
#  'description_word_342_count',
#  'description_word_343_count',
#  'description_word_344_count',
#  'description_word_345_count',
#  'description_word_346_count',
#  'description_word_347_count',
#  'description_word_348_count',
#  'description_word_349_count',
#  'description_word_350_count',
#  'description_word_351_count',
#  'description_word_352_count',
#  'description_word_353_count',
#  'description_word_354_count',
#  'description_word_355_count',
#  'description_word_356_count',
#  'description_word_357_count',
#  'description_word_358_count',
#  'description_word_359_count',
#  'description_word_360_count',
#  'description_word_361_count',
#  'description_word_362_count',
#  'description_word_363_count',
#  'description_word_364_count',
#  'description_word_365_count',
#  'description_word_366_count',
#  'description_word_367_count',
#  'description_word_368_count',
#  'description_word_369_count',
#  'description_word_370_count',
#  'description_word_371_count',
#  'description_word_372_count',
#  'description_word_373_count',
#  'description_word_374_count',
#  'description_word_375_count',
#  'description_word_376_count',
#  'description_word_377_count',
#  'description_word_378_count',
#  'description_word_379_count',
#  'description_word_380_count',
#  'description_word_381_count',
#  'description_word_382_count',
#  'description_word_383_count',
#  'description_word_384_count',
#  'description_word_385_count',
#  'description_word_386_count',
#  'description_word_387_count',
#  'description_word_388_count',
#  'description_word_389_count',
#  'description_word_390_count',
#  'description_word_391_count',
#  'description_word_392_count',
#  'description_word_393_count',
#  'description_word_394_count',
#  'description_word_395_count',
#  'description_word_396_count',
#  'description_word_397_count',
#  'description_word_398_count',
#  'description_word_399_count',
#  'description_word_400_count',
#  'description_word_401_count',
#  'description_word_402_count',
#  'description_word_403_count',
#  'description_word_404_count',
#  'description_word_405_count',
#  'description_word_406_count',
#  'description_word_407_count',
#  'description_word_408_count',
#  'description_word_409_count',
#  'description_word_410_count',
#  'description_word_411_count',
#  'description_word_412_count',
#  'description_word_413_count',
#  'description_word_414_count',
#  'description_word_415_count',
#  'description_word_416_count',
#  'description_word_417_count',
#  'description_word_418_count',
#  'description_word_419_count',
#  'description_word_420_count',
#  'description_word_421_count',
#  'description_word_422_count',
#  'description_word_423_count',
#  'description_word_424_count',
#  'description_word_425_count',
#  'description_word_426_count',
#  'description_word_427_count',
#  'description_word_428_count',
#  'description_word_429_count',
#  'description_word_430_count',
#  'description_word_431_count',
#  'description_word_432_count',
#  'description_word_433_count',
#  'description_word_434_count',
#  'description_word_435_count',
#  'description_word_436_count',
#  'description_word_437_count',
#  'description_word_438_count',
#  'description_word_439_count',
#  'description_word_440_count',
#  'description_word_441_count',
#  'description_word_442_count',
#  'description_word_443_count',
#  'description_word_444_count',
#  'description_word_445_count',
#  'description_word_446_count',
#  'description_word_447_count',
#  'description_word_448_count',
#  'description_word_449_count',
#  'description_word_450_count',
#  'description_word_451_count',
#  'description_word_452_count',
#  'description_word_453_count',
#  'description_word_454_count',
#  'description_word_455_count',
#  'description_word_456_count',
#  'description_word_457_count',
#  'description_word_458_count',
#  'description_word_459_count',
#  'description_word_460_count',
#  'description_word_461_count',
#  'description_word_462_count',
#  'description_word_463_count',
#  'description_word_464_count',
#  'description_word_465_count',
#  'description_word_466_count',
#  'description_word_467_count',
#  'description_word_468_count',
#  'description_word_469_count',
#  'description_word_470_count',
#  'description_word_471_count',
#  'description_word_472_count',
#  'description_word_473_count',
#  'description_word_474_count',
#  'description_word_475_count',
#  'description_word_476_count',
#  'description_word_477_count',
#  'description_word_478_count',
#  'description_word_479_count',
#  'description_word_480_count',
#  'description_word_481_count',
#  'description_word_482_count',
#  'description_word_483_count',
#  'description_word_484_count',
#  'description_word_485_count',
#  'description_word_486_count',
#  'description_word_487_count',
#  'description_word_488_count',
#  'description_word_489_count',
#  'description_word_490_count',
#  'description_word_491_count',
#  'description_word_492_count',
#  'description_word_493_count',
#  'description_word_494_count',
#  'description_word_495_count',
#  'description_word_496_count',
#  'description_word_497_count',
#  'description_word_498_count',
#  'description_word_499_count',
#  'description_word_500_count',
#  'description_word_501_count',
#  'description_word_502_count',
#  'description_word_503_count',
#  'description_word_504_count',
#  'description_word_505_count',
#  'description_word_506_count',
#  'description_word_507_count',
#  'description_word_508_count',
#  'description_word_509_count',
#  'description_word_510_count',
#  'description_word_511_count',
#  'description_word_512_count',
#  'description_word_513_count',
#  'description_word_514_count',
#  'description_word_515_count',
#  'description_word_516_count',
#  'description_word_517_count',
#  'description_word_518_count',
#  'description_word_519_count',
#  'description_word_520_count',
#  'description_word_521_count',
#  'description_word_522_count',
#  'description_word_523_count',
#  'description_word_524_count',
#  'description_word_525_count',
#  'description_word_526_count',
#  'description_word_527_count',
#  'description_word_528_count',
#  'description_word_529_count',
#  'description_word_530_count',
#  'description_word_531_count',
#  'description_word_532_count',
#  'description_word_533_count',
#  'description_word_534_count',
#  'description_word_535_count',
#  'description_word_536_count',
#  'description_word_537_count',
#  'description_word_538_count',
#  'description_word_539_count',
#  'description_word_540_count',
#  'description_word_541_count',
#  'description_word_542_count',
#  'description_word_543_count',
#  'description_word_544_count',
#  'description_word_545_count',
#  'description_word_546_count',
#  'description_word_547_count',
#  'description_word_548_count',
#  'description_word_549_count',
#  'description_word_550_count',
#  'description_word_551_count',
#  'description_word_552_count',
#  'description_word_553_count',
#  'description_word_554_count',
#  'description_word_555_count',
#  'description_word_556_count',
#  'description_word_557_count',
#  'description_word_558_count',
#  'description_word_559_count',
#  'description_word_560_count',
#  'description_word_561_count',
#  'description_word_562_count',
#  'description_word_563_count',
#  'description_word_564_count',
#  'description_word_565_count',
#  'description_word_566_count',
#  'description_word_567_count',
#  'description_word_568_count',
#  'description_word_569_count',
#  'description_word_570_count',
#  'description_word_571_count',
#  'description_word_572_count',
#  'description_word_573_count',
#  'description_word_574_count',
#  'description_word_575_count',
#  'description_word_576_count',
#  'description_word_577_count',
#  'description_word_578_count',
#  'description_word_579_count',
#  'description_word_580_count',
#  'description_word_581_count',
#  'description_word_582_count',
#  'description_word_583_count',
#  'description_word_584_count',
#  'description_word_585_count',
#  'description_word_586_count',
#  'description_word_587_count',
#  'description_word_588_count',
#  'description_word_589_count',
#  'description_word_590_count',
#  'description_word_591_count',
#  'description_word_592_count',
#  'description_word_593_count',
#  'description_word_594_count',
#  'description_word_595_count',
#  'description_word_596_count',
#  'description_word_597_count',
#  'description_word_598_count',
#  'description_word_599_count',
#  'description_word_600_count',
#  'description_word_601_count',
#  'description_word_602_count',
#  'description_word_603_count',
#  'description_word_604_count',
#  'description_word_605_count',
#  'description_word_606_count',
#  'description_word_607_count',
#  'description_word_608_count',
#  'description_word_609_count',
#  'description_word_610_count',
#  'description_word_611_count',
#  'description_word_612_count',
#  'description_word_613_count',
#  'description_word_614_count',
#  'description_word_615_count',
#  'description_word_616_count',
#  'description_word_617_count',
#  'description_word_618_count',
#  'description_word_619_count',
#  'description_word_620_count',
#  'description_word_621_count',
#  'description_word_622_count',
#  'description_word_623_count',
#  'description_word_624_count',
#  'description_word_625_count',
#  'description_word_626_count',
#  'description_word_627_count',
#  'description_word_628_count',
#  'description_word_629_count',
#  'description_word_630_count',
#  'description_word_631_count',
#  'description_word_632_count',
#  'description_word_633_count',
#  'description_word_634_count',
#  'description_word_635_count',
#  'description_word_636_count',
#  'description_word_637_count',
#  'description_word_638_count',
#  'description_word_639_count',
#  'description_word_640_count',
#  'description_word_641_count',
#  'description_word_642_count',
#  'description_word_643_count',
#  'description_word_644_count',
#  'description_word_645_count',
#  'description_word_646_count',
#  'description_word_647_count',
#  'description_word_648_count',
#  'description_word_649_count',
#  'description_word_650_count',
#  'description_word_651_count',
#  'description_word_652_count',
#  'description_word_653_count',
#  'description_word_654_count',
#  'description_word_655_count',
#  'description_word_656_count',
#  'description_word_657_count',
#  'description_word_658_count',
#  'description_word_659_count',
#  'description_word_660_count',
#  'description_word_661_count',
#  'description_word_662_count',
#  'description_word_663_count',
#  'description_word_664_count',
#  'description_word_665_count',
#  'description_word_666_count',
#  'description_word_667_count',
#  'description_word_668_count',
#  'description_word_669_count',
#  'description_word_670_count',
#  'description_word_671_count',
#  'description_word_672_count',
#  'description_word_673_count',
#  'description_word_674_count',
#  'description_word_675_count',
#  'description_word_676_count',
#  'description_word_677_count',
#  'description_word_678_count',
#  'description_word_679_count',
#  'description_word_680_count',
#  'description_word_681_count',
#  'description_word_682_count',
#  'description_word_683_count',
#  'description_word_684_count',
#  'description_word_685_count',
#  'description_word_686_count',
#  'description_word_687_count',
#  'description_word_688_count',
#  'description_word_689_count',
#  'description_word_690_count',
#  'description_word_691_count',
#  'description_word_692_count',
#  'description_word_693_count',
#  'description_word_694_count',
#  'description_word_695_count',
#  'description_word_696_count',
#  'description_word_697_count',
#  'description_word_698_count',
#  'description_word_699_count',
#  'description_word_700_count',
#  'description_word_701_count',
#  'description_word_702_count',
#  'description_word_703_count',
#  'description_word_704_count',
#  'description_word_705_count',
#  'description_word_706_count',
#  'description_word_707_count',
#  'description_word_708_count',
#  'description_word_709_count',
#  'description_word_710_count',
#  'description_word_711_count',
#  'description_word_712_count',
#  'description_word_713_count',
#  'description_word_714_count',
#  'description_word_715_count',
#  'description_word_716_count',
#  'description_word_717_count',
#  'description_word_718_count',
#  'description_word_719_count',
#  'description_word_720_count',
#  'description_word_721_count',
#  'description_word_722_count',
#  'description_word_723_count',
#  'description_word_724_count',
#  'description_word_725_count',
#  'description_word_726_count',
#  'description_word_727_count',
#  'description_word_728_count',
#  'description_word_729_count',
#  'description_word_730_count',
#  'description_word_731_count',
#  'description_word_732_count',
#  'description_word_733_count',
#  'description_word_734_count',
#  'description_word_735_count',
#  'description_word_736_count',
#  'description_word_737_count',
#  'description_word_738_count',
#  'description_word_739_count',
#  'description_word_740_count',
#  'description_word_741_count',
#  'description_word_742_count',
#  'description_word_743_count',
#  'description_word_744_count',
#  'description_word_745_count',
#  'description_word_746_count',
#  'description_word_747_count',
#  'description_word_748_count',
#  'description_word_749_count',
#  'tags_word_0_count',
#  'tags_word_1_count',
#  'tags_word_2_count',
#  'tags_word_3_count',
#  'tags_word_4_count',
#  'tags_word_5_count',
#  'tags_word_6_count',
#  'tags_word_7_count',
#  'tags_word_8_count',
#  'tags_word_9_count',
#  'tags_word_10_count',
#  'tags_word_11_count',
#  'tags_word_12_count',
#  'tags_word_13_count',
#  'tags_word_14_count',
#  'tags_word_15_count',
#  'tags_word_16_count',
#  'tags_word_17_count',
#  'tags_word_18_count',
#  'tags_word_19_count',
#  'tags_word_20_count',
#  'tags_word_21_count',
#  'tags_word_22_count',
#  'tags_word_23_count',
#  'tags_word_24_count',
#  'tags_word_25_count',
#  'tags_word_26_count',
#  'tags_word_27_count',
#  'tags_word_28_count',
#  'tags_word_29_count',
#  'tags_word_30_count',
#  'tags_word_31_count',
#  'tags_word_32_count',
#  'tags_word_33_count',
#  'tags_word_34_count',
#  'tags_word_35_count',
#  'tags_word_36_count',
#  'tags_word_37_count',
#  'tags_word_38_count',
#  'tags_word_39_count',
#  'tags_word_40_count',
#  'tags_word_41_count',
#  'tags_word_42_count',
#  'tags_word_43_count',
#  'tags_word_44_count',
#  'tags_word_45_count',
#  'tags_word_46_count',
#  'tags_word_47_count',
#  'tags_word_48_count',
#  'tags_word_49_count',
#  'tags_word_50_count',
#  'tags_word_51_count',
#  'tags_word_52_count',
#  'tags_word_53_count',
#  'tags_word_54_count',
#  'tags_word_55_count',
#  'tags_word_56_count',
#  'tags_word_57_count',
#  'tags_word_58_count',
#  'tags_word_59_count',
#  'tags_word_60_count',
#  'tags_word_61_count',
#  'tags_word_62_count',
#  'tags_word_63_count',
#  'tags_word_64_count',
#  'tags_word_65_count',
#  'tags_word_66_count',
#  'tags_word_67_count',
#  'tags_word_68_count',
#  'tags_word_69_count',
#  'tags_word_70_count',
#  'tags_word_71_count',
#  'tags_word_72_count',
#  'tags_word_73_count',
#  'tags_word_74_count',
#  'tags_word_75_count',
#  'tags_word_76_count',
#  'tags_word_77_count',
#  'tags_word_78_count',
#  'tags_word_79_count',
#  'tags_word_80_count',
#  'tags_word_81_count',
#  'tags_word_82_count',
#  'tags_word_83_count',
#  'tags_word_84_count',
#  'tags_word_85_count',
#  'tags_word_86_count',
#  'tags_word_87_count',
#  'tags_word_88_count',
#  'tags_word_89_count',
#  'tags_word_90_count',
#  'tags_word_91_count',
#  'tags_word_92_count',
#  'tags_word_93_count',
#  'tags_word_94_count',
#  'tags_word_95_count',
#  'tags_word_96_count',
#  'tags_word_97_count',
#  'tags_word_98_count',
#  'tags_word_99_count',
#  'tags_word_100_count',
#  'tags_word_101_count',
#  'tags_word_102_count',
#  'tags_word_103_count',
#  'tags_word_104_count',
#  'tags_word_105_count',
#  'tags_word_106_count',
#  'tags_word_107_count',
#  'tags_word_108_count',
#  'tags_word_109_count',
#  'tags_word_110_count',
#  'tags_word_111_count',
#  'tags_word_112_count',
#  'tags_word_113_count',
#  'tags_word_114_count',
#  'tags_word_115_count',
#  'tags_word_116_count',
#  'tags_word_117_count',
#  'tags_word_118_count',
#  'tags_word_119_count',
#  'tags_word_120_count',
#  'tags_word_121_count',
#  'tags_word_122_count',
#  'tags_word_123_count',
#  'tags_word_124_count',
#  'tags_word_125_count',
#  'tags_word_126_count',
#  'tags_word_127_count',
#  'tags_word_128_count',
#  'tags_word_129_count',
#  'tags_word_130_count',
#  'tags_word_131_count',
#  'tags_word_132_count',
#  'tags_word_133_count',
#  'tags_word_134_count',
#  'tags_word_135_count',
#  'tags_word_136_count',
#  'tags_word_137_count',
#  'tags_word_138_count',
#  'tags_word_139_count',
#  'tags_word_140_count',
#  'tags_word_141_count',
#  'tags_word_142_count',
#  'tags_word_143_count',
#  'tags_word_144_count',
#  'tags_word_145_count',
#  'tags_word_146_count',
#  'tags_word_147_count',
#  'tags_word_148_count',
#  'tags_word_149_count',
#  'tags_word_150_count',
#  'tags_word_151_count',
#  'tags_word_152_count',
#  'tags_word_153_count',
#  'tags_word_154_count',
#  'tags_word_155_count',
#  'tags_word_156_count',
#  'tags_word_157_count',
#  'tags_word_158_count',
#  'tags_word_159_count',
#  'tags_word_160_count',
#  'tags_word_161_count',
#  'tags_word_162_count',
#  'tags_word_163_count',
#  'tags_word_164_count',
#  'tags_word_165_count',
#  'tags_word_166_count',
#  'tags_word_167_count',
#  'tags_word_168_count',
#  'tags_word_169_count',
#  'tags_word_170_count',
#  'tags_word_171_count',
#  'tags_word_172_count',
#  'tags_word_173_count',
#  'tags_word_174_count',
#  'tags_word_175_count',
#  'tags_word_176_count',
#  'tags_word_177_count',
#  'tags_word_178_count',
#  'tags_word_179_count',
#  'tags_word_180_count',
#  'tags_word_181_count',
#  'tags_word_182_count',
#  'tags_word_183_count',
#  'tags_word_184_count',
#  'tags_word_185_count',
#  'tags_word_186_count',
#  'tags_word_187_count',
#  'tags_word_188_count',
#  'tags_word_189_count',
#  'tags_word_190_count',
#  'tags_word_191_count',
#  'tags_word_192_count',
#  'tags_word_193_count',
#  'tags_word_194_count',
#  'tags_word_195_count',
#  'tags_word_196_count',
#  'tags_word_197_count',
#  'tags_word_198_count',
#  'tags_word_199_count',
#  'tags_word_200_count',
#  'tags_word_201_count',
#  'tags_word_202_count',
#  'tags_word_203_count',
#  'tags_word_204_count',
#  'tags_word_205_count',
#  'tags_word_206_count',
#  'tags_word_207_count',
#  'tags_word_208_count',
#  'tags_word_209_count',
#  'tags_word_210_count',
#  'tags_word_211_count',
#  'tags_word_212_count',
#  'tags_word_213_count',
#  'tags_word_214_count',
#  'tags_word_215_count',
#  'tags_word_216_count',
#  'tags_word_217_count',
#  'tags_word_218_count',
#  'tags_word_219_count',
#  'tags_word_220_count',
#  'tags_word_221_count',
#  ...]

# %%
clf = LinearRegression()

_ = clf.fit(X_trn[cat_num_cols], y_trn)

preds_val = clf.predict(X_val[cat_num_cols])

av_metric_score = av_metric(y_val, preds_val)

print(f'AV metric score is: {av_metric_score}')
# Out:
# AV metric score is: 650.0452072359827

# %% [markdown]
# Tried using Random Search to get best parameters. Unfortunately the training took more than an hour. (Please skip this section)

# %%
from sklearn.model_selection import RandomizedSearchCV

hyperparam_combs = {
    'max_depth': [4, 6, 8, 10, 12],
    'min_samples_split': [2, 10, 20, 30, 40],
    'max_features': [0.2, 0.4, 0.6, 0.8, 1],
    'max_leaf_nodes': [8, 16, 32, 64, 128],
}

clf = RandomizedSearchCV(RandomForestRegressor(),
                         hyperparam_combs,
                         scoring='neg_root_mean_squared_error',
                         random_state=1,
                         n_iter=20)

search = clf.fit(df[cat_num_cols], df[TARGET_COL])

search.best_params_

# %% [markdown]
# Selecting maximum parameters to save training time.

# %%
best_params = {'max_depth': 12,
 'max_features': 0.8,
 'max_leaf_nodes': 128,
 'random_state': 1,
 'min_samples_split': 30}

clf = RandomForestRegressor(**best_params)

_ = clf.fit(X_trn[cat_num_cols], y_trn)

preds_val = clf.predict(X_val[cat_num_cols])

av_metric_score = av_metric(y_val, preds_val)

print(f'AV metric score is: {av_metric_score}')
# Out:
# AV metric score is: 588.1135462877477

# %% [markdown]
# The closer the RMSE value to zero the better the performance. In this ML model the data in millions range knowing that we did best.
